# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
weights=[120, 140, 160, 190, 205, 230, 250, 270, 332]

# %%
hours=[2, 3, 4, 5, 6, 7, 8, 10, 12]

# %%
health_index=[9, 8.5, 6.3, 5.6, 5.6, 4.6, 4, 3.5, 3]

# %%
plt.plot(hours, weights,'bo')
plt.xlabel('Hours')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')

# %%
plt.plot(hours, health_index, "ro")
plt.xlabel( "Hours")
plt.ylabel("health_index")
# Out:
# Text(0, 0.5, 'health_index')

# %%
hours_practiced=[.1,.2, .3, .5, .7, .8, 1]

# %%
#goals_missed_for_hours_practiced=[1, 2, 3, 4, 5, 6, 7]

# %%
hours_not_practiced=[16, 24, 48, 52, 76, 90, 100]

# %%
goals_scored_for_not_practiced=[1, .8, .7, .6, .5, .4, .3]

# %%
plt.plot(hours_practiced, goals_scored_for_hours_practiced, "ko")
plt.xlabel("hours practiced")
plt.ylabel("goasls scored for hours practiced")
# Out:
# Text(0, 0.5, 'goasls scored for hours practiced')

# %%
plt.figure(figsize=(10,6));
team_names=["P.S.G", "Barcelona", "Tottenham", "Liverpool", "Chelse", "Machester United"]
Goals=[7, 3, 4, 4, 5, 6]
plt.bar(team_names, Goals)

plt.ylabel("Goals")
# Out:
# Text(0, 0.5, 'Goals')
